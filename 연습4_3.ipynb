# %% [markdown]
# <a href="https://colab.research.google.com/github/JeenChoi/hello_world/blob/master/%EC%97%B0%EC%8A%B54_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %%
url = "https://data.cityofnewyork.us/resource/fhrw-4uyv.csv"

# %%
taxi_service = pd.read_csv(url)

# %%
taxi_service[:15]
# Out:
#     address_type agency                              agency_name  \
# 0   INTERSECTION    DOT             Department of Transportation
# 1        ADDRESS    DOT             Department of Transportation
# 2   INTERSECTION    DOT             Department of Transportation
# 3   INTERSECTION    DOT             Department of Transportation
# 4        ADDRESS   NYPD          New York City Police Department
# 5        ADDRESS   NYPD          New York City Police Department
# 6        ADDRESS   DSNY                 Department of Sanitation
# 7        ADDRESS   NYPD          New York City Police Department
# 8        ADDRESS   NYPD          New York City Police Department
# 9        ADDRESS   NYPD          New York City Police Department
# 10       LATLONG  DOHMH  Department of Health and Mental Hygiene
# 11       ADDRESS   NYPD          New York City Police Department
# 12       ADDRESS    DOT             Department of Transportation
# ...

# %%
taxi_adress = taxi_service[taxi_service['address_type'] == "ADDRESS"]
taxi_adress[:4]
# Out:
#   address_type agency                      agency_name           bbl  \
# 1      ADDRESS    DOT     Department of Transportation  3.066800e+09
# 4      ADDRESS   NYPD  New York City Police Department  4.006730e+09
# 5      ADDRESS   NYPD  New York City Police Department  4.014920e+09
# 6      ADDRESS   DSNY         Department of Sanitation  4.035460e+09
#
#     borough  bridge_highway_direction  bridge_highway_name  \
# 1  BROOKLYN                       NaN                  NaN
# 4    QUEENS                       NaN                  NaN
# 5    QUEENS                       NaN                  NaN
# 6    QUEENS                       NaN                  NaN
#
#    bridge_highway_segment              city closed_date  \
# 1                     NaN          BROOKLYN         NaN
# 4                     NaN  LONG ISLAND CITY         NaN
# 5                     NaN          ELMHURST         NaN
# 6                     NaN         Ridgewood         NaN
#
#              ...             \
# ...

# %%
taxi_service['address_type'] == "ADDRESS"
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10     False
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17     False
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25     False
# 26      True
# 27      True
# 28      True
# 29     False
#        ...
# 970     True
# 971     True
# 972     True
# 973     True
# 974     True
# 975     True
# 976     True
# 977     True
# 978     True
# 979     True
# 980     True
# 981     True
# 982     True
# 983     True
# 984     True
# 985     True
# 986     True
# 987     True
# 988     True
# 989     True
# 990     True
# 991     True
# 992     True
# 993     True
# 994     True
# 995     True
# 996     True
# 997    False
# 998     True
# 999     True
# Name: address_type, Length: 1000, dtype: bool

# %%
is_address = taxi_service['address_type'] == "ADDRESS"
is_Queens = taxi_service['borough'] == "QUEENS"
taxi_service[is_address & is_Queens][:6]
# Out:
#    address_type agency                      agency_name           bbl borough  \
# 4       ADDRESS   NYPD  New York City Police Department  4.006730e+09  QUEENS
# 5       ADDRESS   NYPD  New York City Police Department  4.014920e+09  QUEENS
# 6       ADDRESS   DSNY         Department of Sanitation  4.035460e+09  QUEENS
# 7       ADDRESS   NYPD  New York City Police Department  4.015230e+09  QUEENS
# 8       ADDRESS   NYPD  New York City Police Department  4.115120e+09  QUEENS
# 16      ADDRESS   NYPD  New York City Police Department  4.119600e+09  QUEENS
#
#     bridge_highway_direction  bridge_highway_name  bridge_highway_segment  \
# 4                        NaN                  NaN                     NaN
# 5                        NaN                  NaN                     NaN
# 6                        NaN                  NaN                     NaN
# 7                        NaN                  NaN                     NaN
# ...

# %%
taxi_service[is_address & is_Queens][['address_type', 'borough', 'agency', 'bbl']][:11]
# Out:
#    address_type borough agency           bbl
# 4       ADDRESS  QUEENS   NYPD  4.006730e+09
# 5       ADDRESS  QUEENS   NYPD  4.014920e+09
# 6       ADDRESS  QUEENS   DSNY  4.035460e+09
# 7       ADDRESS  QUEENS   NYPD  4.015230e+09
# 8       ADDRESS  QUEENS   NYPD  4.115120e+09
# 16      ADDRESS  QUEENS   NYPD  4.119600e+09
# 19      ADDRESS  QUEENS   NYPD  4.092300e+09
# 20      ADDRESS  QUEENS   NYPD  4.036840e+09
# 21      ADDRESS  QUEENS   NYPD  4.013120e+09
# 26      ADDRESS  QUEENS   NYPD  4.090220e+09
# 31      ADDRESS  QUEENS   NYPD  4.001890e+09

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
pd.Series([1,2,3,]).values
# Out:
# array([1, 2, 3])

# %%
arr = np.array([1,2,3])

# %%
arr != 2
# Out:
# array([ True, False,  True])

# %%
arr[arr != 2]
# Out:
# array([1, 3])

# %%
is_address = taxi_service['address_type'] == "ADDRESS"
address = taxi_service[is_address]
address['borough'].value_counts()
# Out:
# QUEENS           279
# BROOKLYN         249
# MANHATTAN        175
# BRONX            163
# STATEN ISLAND     34
# Name: borough, dtype: int64

# %%
address_counts = addresstype['borough'].value_counts()
address_type_counts = taxi_service['borough'].value_counts()

# %%
address_counts / address_type_counts
# Out:
# BRONX            0.958824
# BROOKLYN         0.912088
# MANHATTAN        0.897436
# QUEENS           0.882911
# STATEN ISLAND    0.809524
# Unspecified           NaN
# Name: borough, dtype: float64

# %%
address_counts / address_type_counts.astype(float)
# Out:
# BRONX            0.958824
# BROOKLYN         0.912088
# MANHATTAN        0.897436
# QUEENS           0.882911
# STATEN ISLAND    0.809524
# Unspecified           NaN
# Name: borough, dtype: float64

# %%
(address_counts / address_type_counts.astype(float)).plot(kind='bar')

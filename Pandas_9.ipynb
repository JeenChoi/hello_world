# %% [markdown]
# <a href="https://colab.research.google.com/github/JeenChoi/hello_world/blob/master/Pandas_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2c206539-02ce-4434-81df-83bf291eea52" name="files[]" multiple disabled />
#      <output id="result-2c206539-02ce-4434-81df-83bf291eea52">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weather_2012.sqlite to weather_2012.sqlite
# {'weather_2012.sqlite': b'SQLite format 3\x00\x04\x00\x01\x01\x00@  -\xe2%\r\x00\x00\x00\x02\x02\xec\x00\x03>P\x02\x06\x17++\x01Ytablesqlite_sequencesqlite_sequence\x03CREATE TABLE sqlite_sequence(name,seq)\x81?\x01\x07\x17%%\x01\x82Atableweather_2012weather_2012\x02CREATE TABLE weather_2012 (\n            id INTEGER PRIMARY KEY AUTOINCREMENT,\n            date_time TIMESTAMP,\n            temp DOUBLE PRECISION\n        )\x05\x00\x00\x00\x03\x03\xf1\x00\x00\x00\x00\x07\x03\xfb\x03\xf6\x03\xf1\x03:\x03\x19\x02\xf8\x02\xd7\x02\xb6\x02\x9c\x02{\x02Z\x029\x02\x18\x01\xf7\x01\xd6\x01\xbc\x01\x9b\x01z\x01Y\x01?\x01\x1e\x00\xfd\x00\xdc\x00\xbb\x00\x9a\x00y\x00X\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x1f\x1d\x04\x003\x072012-01-02 04:00:00@\x07333333\x1f\x1c\x04\x003\x072012-01-02 03:00:00@\r\x99\x99\x99\x99\x99\x9a\x1f\x1b\x04\x003\x072012-01-02 02:00:00@\x0f333333\x1f\x1a\x04\x003\x072012-01-02 01:00:00@\x12ffffff\x1f\x19\x04\x003\x072012-01-02 00:00:00@\x14\xcc\xcc\xcc\xcc\xcc\xcd\x1f\x18\x04\x003\x072012-01-01 23:00:00@\x15333333\x1f\x17\x04\x003\x072012-01-01 22:00:00@\x11\x99\x99\x99\x99\x99\ ...

# %%
con = sqlite3.connect("weather_2012.sqlite")
df = pd.read_sql("SELECT * from weather_2012 LIMIT 3", con)
df
# Out:
#    id            date_time  temp
# 0   1  2012-01-01 00:00:00  -1.8
# 1   2  2012-01-01 01:00:00  -1.8
# 2   3  2012-01-01 02:00:00  -1.8

# %%
df = pd.read_sql("SELECT * from weather_2012 LIMIT 3", con, index_col='id')
df
# Out:
#               date_time  temp
# id
# 1   2012-01-01 00:00:00  -1.8
# 2   2012-01-01 01:00:00  -1.8
# 3   2012-01-01 02:00:00  -1.8

# %%
df = pd.read_sql("SELECT * from weather_2012 LIMIT 3", con, 
                 index_col=['id', 'date_time'])
df
# Out:
#                         temp
# id date_time
# 1  2012-01-01 00:00:00  -1.8
# 2  2012-01-01 01:00:00  -1.8
# 3  2012-01-01 02:00:00  -1.8

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9c8d3dd6-13ea-4828-915f-81ad6c137d3c" name="files[]" multiple disabled />
#      <output id="result-9c8d3dd6-13ea-4828-915f-81ad6c137d3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weather_2012.csv to weather_2012 (1).csv
# {'weather_2012.csv': b'Date/Time,Dew Point Temp (C),Rel Hum (%),Stn Press (kPa),Temp (C),Visibility (km),Weather,Wind Spd (km/h)\n2012-01-01 00:00:00,-3.9,86.0,101.24,-1.8,8.0,Fog,4.0\n2012-01-01 01:00:00,-3.7,87.0,101.24,-1.8,8.0,Fog,4.0\n2012-01-01 02:00:00,-3.4,89.0,101.26,-1.8,4.0,"Freezing Drizzle,Fog",7.0\n2012-01-01 03:00:00,-3.2,88.0,101.27,-1.5,4
0\n2012-01-02 16:00:00,-8.7,55.0,99.5,-0.7,24.1,Mostly Cloudy,24.0\n2012-01-02 17:00:00,-9.5,57.0,99.66,-2.1,25.0,Snow Showers,22.0\n2012-01-02 18:00:00,-11.4,57.0,99.86,-4.1,25.0,Mostly Cloudy,28.0\n2012-01-02 19:00:00,-12.1,57.0,100.0,-4.8,25.0,Mostly Cloudy,24.0\n2012-01-02 20:00:00,-13.4,54.0,100.07,-5.6,25.0,Snow Showers,24.0\n2012-01-02 21:00:00,-12.8,58.0,100.15,-5.8,25.0,Snow Showers,26.0\n2012-01-02 22:00:00,-14.7,54.0,100.26,-7.0,25.0,Cloudy,20.0\n2012-01-02 23:00:00,-14.1,59.0,100.27,-7.4,19.3,Snow Showers,17.0\n2012-01-03 00:00:00,-16.0,57.0,100.35,-9.0,25.0,Snow Showers,28.0\n2012-01-03 01:00:00,-17.2,54.0,100.43,-9.7,25.0,Cloudy,20.0\n2012-01-03 02:00:00,-15.8,65.0,100.53,-10.5,12.9,Snow Showers,22.0\n2012-01-03 03:00:00,-18.7,54.0,100.61,-11.3,25.0,Snow Showers,33.0\n2012-01-03 04:00:00,-20.1,53.0,100.68,-12.6,25.0,Cloudy,24.0\n2012-01-03 05:00:00,-19.1,60.0,100.76,-12.9,25.0,Snow Showers,22.0\n2012-01-03 06:00:00,-19.3,61.0,100.85,-13.3,25.0,Snow Showers,19.0\n2012-01-03 07:00:00,-19.5,63.0,100.95,-14.0,25.0,Snow,19.0\n2012-01-03 08:00:00,-21.3,58.0,101.07,-14.8,24.1,Mostly Cloudy,26.0\n2012-01-03 09:00:00,-21.9,56.0,101.2,-15.0,24.1,Mostly Cloudy,19.0\n2012-01-03 10:00:00,-22.2,56.0,101.29,-15.3,24.1,Cloudy,24.0\n2012-01-03 11:00:00,-22.2,54.0,101.33,-14.9,24.1,Mostly Cloudy,22.0\n2012-01-03 12:00:00,-22.6,52.0,101.34,-14.9,24.1,Mainly Clear,20.0\n2012-01-03 13:00:00,-22.4,54.0,101.34,-15.1,24.1,Mainly Clear,22.0\n2012-01 ...

# %%
weather_df = pd.read_csv('weather_2012.csv')
con = sqlite3.connect("test_db.sqlite")
con.execute("DROP TABLE IF EXISTS weather_2012")
weather_df.to_sql("weather_2012", con)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:1534: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %%
con = sqlite3.connect("test_db.sqlite")
df = pd.read_sql("SELECT * from weather_2012 LIMIT 3", con)
df
# Out:
#    index            Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0      0  2013-01-01 00:00:00      -1.0                -1.7           95
# 1      1  2013-01-01 01:00:00      -2.0                -5.1           79
# 2      2  2013-01-01 02:00:00      -2.7                -6.0           78
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)       Weather
# 0               35              6.4            99.89          Snow
# 1               35             16.1            99.93  Mainly Clear
# 2               28             19.3           100.08          Snow

# %%
con = sqlite3.connect("test_db.sqlite")
df = pd.read_sql("SELECT * from weather_2012 ORDER BY Weather LIMIT 3", con)
df
# Out:
#    index            Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0      3  2013-01-01 03:00:00      -5.6               -11.7           62
# 1      5  2013-01-01 05:00:00      -9.7               -14.8           66
# 2      6  2013-01-01 06:00:00     -11.1               -17.0           62
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 0               30             25.0           100.21   Clear
# 1               33             25.0           100.47   Clear
# 2               30             25.0           100.65   Clear

# %% [markdown]
# <a href="https://colab.research.google.com/github/JeenChoi/hello_world/blob/master/Pandas_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from pandas import Series

# %%
plt.rcParams['figure.figsize'] = (15,5)
plt.rcParams['font.family'] = 'sans-serif'

# %%
pd.set_option?

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e1ce6ae0-ef5e-4c8c-ad17-2ec403283ffb" name="files[]" multiple disabled />
#      <output id="result-e1ce6ae0-ef5e-4c8c-ad17-2ec403283ffb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weather_2012.csv to weather_2012 (4).csv
# ...

# %%
files.upload?

# %%
pd.read_csv?

# %%
weather_2012 = pd.read_csv('weather_2012.csv', parse_dates= True, index_col='Date/Time')

# %%
weather_2012[:4]
# Out:
#                      Dew Point Temp (C)  Rel Hum (%)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                -3.9         86.0           101.24
# 2012-01-01 01:00:00                -3.7         87.0           101.24
# 2012-01-01 02:00:00                -3.4         89.0           101.26
# 2012-01-01 03:00:00                -3.2         88.0           101.27
#
#                      Temp (C)  Visibility (km)               Weather  \
# Date/Time
# 2012-01-01 00:00:00      -1.8              8.0                   Fog
# 2012-01-01 01:00:00      -1.8              8.0                   Fog
# 2012-01-01 02:00:00      -1.8              4.0  Freezing Drizzle,Fog
# 2012-01-01 03:00:00      -1.5              4.0  Freezing Drizzle,Fog
#
#                      Wind Spd (km/h)
# Date/Time
# 2012-01-01 00:00:00              4.0
# 2012-01-01 01:00:00              4.0
# 2012-01-01 02:00:00              7.0
# 2012-01-01 03:00:00              6.0

# %%
weather_description = weather_2012['Weather']
hour_snowing = weather_description.str.contains("Snow")

# %%
weather_description.str.contains?

# %%
hour_snowing[:7]
# Out:
# Date/Time
# 2012-01-01 00:00:00    False
# 2012-01-01 01:00:00    False
# 2012-01-01 02:00:00    False
# 2012-01-01 03:00:00    False
# 2012-01-01 04:00:00    False
# 2012-01-01 05:00:00    False
# 2012-01-01 06:00:00    False
# Name: Weather, dtype: object

# %%
hour_snowing.astype(bool)[:7]
# Out:
# Date/Time
# 2012-01-01 00:00:00    False
# 2012-01-01 01:00:00    False
# 2012-01-01 02:00:00    False
# 2012-01-01 03:00:00    False
# 2012-01-01 04:00:00    False
# 2012-01-01 05:00:00    False
# 2012-01-01 06:00:00    False
# Name: Weather, dtype: bool

# %%
hour_snowing2 = hour_snowing.astype(float)
hour_snowing2[:5]
# Out:
# Date/Time
# 2012-01-01 00:00:00    0.0
# 2012-01-01 01:00:00    0.0
# 2012-01-01 02:00:00    0.0
# 2012-01-01 03:00:00    0.0
# 2012-01-01 04:00:00    0.0
# Name: Weather, dtype: float64

# %%
hour_snowing2.plot(kind='bar')

# %%
weather_2012['Temp (C)'].resample('M').apply(np.median).plot(kind='bar')

# %%
hour_snowing.astype(float)[:10]
# Out:
# Date/Time
# 2012-01-01 00:00:00    0.0
# 2012-01-01 01:00:00    0.0
# 2012-01-01 02:00:00    0.0
# 2012-01-01 03:00:00    0.0
# 2012-01-01 04:00:00    0.0
# 2012-01-01 05:00:00    0.0
# 2012-01-01 06:00:00    0.0
# 2012-01-01 07:00:00    0.0
# 2012-01-01 08:00:00    0.0
# 2012-01-01 09:00:00    0.0
# Name: Weather, dtype: float64

# %%
hour_snowing.astype(float).resample('M').apply(np.mean)
# Out:
# Date/Time
# 2011-02-28    0.275298
# 2011-03-31    0.129032
# 2011-04-30    0.034722
# 2011-05-31    0.000000
# 2011-06-30    0.000000
# 2011-07-31    0.000000
# 2011-08-31         NaN
# 2011-09-30    0.000000
# 2011-10-31    0.000000
# 2011-11-30    0.020833
# 2011-12-31    0.138441
# 2012-01-31    0.240591
# Freq: M, Name: Weather, dtype: float64

# %%
hour_snowing.astype(float).resample('M').apply(np.mean).plot(kind='bar')

# %%
temperature = weather_2012['Temp (C)'].resample('M').apply(np.median)
is_snowing = weather_2012['Weather'].str.contains('Snow')
snowiness = is_snowing.astype(float).resample('M').apply(np.mean)

# %%
temperature.name = "Temperature"
snowiness.name = "Snowiness"

# %%
snowiness.name?

# %%
stats = pd.concat([temperature, snowiness], axis = 1)
stats
# Out:
#             Temperature  Snowiness
# Date/Time
# 2011-02-28        -7.50   0.275298
# 2011-03-31        -0.90   0.129032
# 2011-04-30         6.00   0.034722
# 2011-05-31        14.10   0.000000
# 2011-06-30        19.20   0.000000
# 2011-07-31        23.30   0.000000
# 2011-08-31          NaN        NaN
# 2011-09-30        18.00   0.000000
# 2011-10-31         9.85   0.000000
# 2011-11-30         5.60   0.020833
# 2011-12-31        -0.90   0.138441
# 2012-01-31        -7.05   0.240591

# %%
pd.concat?

# %%
stats.plot(kind = 'bar')

# %%
stats.plot(kind='bar', subplots=True, figsize=(15, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f8cc874b8d0>,
# ...
#       dtype=object)

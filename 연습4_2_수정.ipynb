# %% [markdown]
# <a href="https://colab.research.google.com/github/JeenChoi/hello_world/blob/master/%EC%97%B0%EC%8A%B54_2_%EC%88%98%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
url = "https://data.cityofnewyork.us/resource/fhrw-4uyv.csv"

# %%
complaints = pd.read_csv(url_template)

# %%
complaints[:5]
# Out:
#   address_type agency                              agency_name           bbl  \
# 0      ADDRESS   DSNY                 Department of Sanitation  3.059990e+09
# 1      ADDRESS   NYPD          New York City Police Department  1.018430e+09
# 2      ADDRESS   NYPD          New York City Police Department  1.010080e+09
# 3          NaN  DOHMH  Department of Health and Mental Hygiene           NaN
# 4      ADDRESS   NYPD          New York City Police Department  2.058781e+09
#
#        borough bridge_highway_direction bridge_highway_name  \
# 0     BROOKLYN                      NaN                 NaN
# 1    MANHATTAN                      NaN                 NaN
# 2    MANHATTAN                      NaN                 NaN
# 3  Unspecified                      NaN                 NaN
# 4        BRONX                      NaN                 NaN
#
#   bridge_highway_segment      city              closed_date  \
# 0                    NaN  BROOKLYN                      NaN
# ...

# %%
complaints['borough'][:5]
# Out:
# 0       BROOKLYN
# 1      MANHATTAN
# 2      MANHATTAN
# 3    Unspecified
# 4          BRONX
# Name: borough, dtype: object

# %%
complaints[['borough', 'agency']]
# Out:
#            borough agency
# 0         BROOKLYN   DSNY
# 1        MANHATTAN   NYPD
# 2        MANHATTAN   NYPD
# 3      Unspecified  DOHMH
# 4            BRONX   NYPD
# 5        MANHATTAN   NYPD
# 6         BROOKLYN   NYPD
# 7           QUEENS   NYPD
# 8           QUEENS   NYPD
# 9           QUEENS  DOHMH
# 10        BROOKLYN   NYPD
# 11           BRONX   NYPD
# 12          QUEENS   NYPD
# 13           BRONX   NYPD
# 14           BRONX   NYPD
# 15        BROOKLYN   NYPD
# 16       MANHATTAN   NYPD
# 17       MANHATTAN   NYPD
# 18           BRONX   NYPD
# 19           BRONX    DOT
# 20           BRONX   NYPD
# 21       MANHATTAN   NYPD
# 22        BROOKLYN   NYPD
# 23          QUEENS   NYPD
# 24        BROOKLYN   NYPD
# 25          QUEENS   NYPD
# 26       MANHATTAN   NYPD
# 27       MANHATTAN   NYPD
# 28        BROOKLYN   NYPD
# 29       MANHATTAN   NYPD
# ..             ...    ...
# 970      MANHATTAN   NYPD
# 971       BROOKLYN   NYPD
# 972         QUEENS   DSNY
# ...

# %%
complaints[['borough', 'agency']][:13]
# Out:
#         borough agency
# 0      BROOKLYN   DSNY
# 1     MANHATTAN   NYPD
# 2     MANHATTAN   NYPD
# 3   Unspecified  DOHMH
# 4         BRONX   NYPD
# 5     MANHATTAN   NYPD
# 6      BROOKLYN   NYPD
# 7        QUEENS   NYPD
# 8        QUEENS   NYPD
# 9        QUEENS  DOHMH
# 10     BROOKLYN   NYPD
# 11        BRONX   NYPD
# 12       QUEENS   NYPD

# %%
complaints['borough'].value_counts()
# Out:
# BROOKLYN         310
# QUEENS           235
# MANHATTAN        226
# BRONX            183
# STATEN ISLAND     41
# Unspecified        5
# Name: borough, dtype: int64

# %%
complaint_counts = complaints['borough'].value_counts()
complaint_counts[:2]
# Out:
# BROOKLYN    310
# QUEENS      235
# Name: borough, dtype: int64

# %%
complaint_counts[:3].plot(kind = 'bar')

# %%
complaint_counts[:3].plot(kind = 'line')

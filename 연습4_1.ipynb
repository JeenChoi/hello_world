# %% [markdown]
# <a href="https://colab.research.google.com/github/JeenChoi/hello_world/blob/master/%EC%97%B0%EC%8A%B54_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
mpl.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)

# %%
plt.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.mencoder_args': [],
#           'animation.mencoder_path': 'mencoder',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': 'white',
#           'axes.facecolor': '#E5E5E5',
#           'axes.formatter.limits': [-7, 7],
#           'axes.formatter.min_exponent': 0,
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-85112e12-e6a8-43b4-80de-40f9a1417dce" name="files[]" multiple disabled />
#      <output id="result-85112e12-e6a8-43b4-80de-40f9a1417dce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bikes.csv to bikes.csv
# ...

# %%
broken_df = pd.read_csv('bikes.csv')
broken_df[:3]
# Out:
#          Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0  01/01/2012      00:00                 16      35             51
# 1  02/01/2012      00:00                 43      83            153
# 2  03/01/2012      00:00                 58     135            248
#
#    Maisonneuve_1  Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# 0             38      5.0    26       10                            0
# 1             68     11.0    53        6                            1
# 2            104      2.0    89        3                            2
#
#    Pont_Jacques_Cartier
# 0                  27.0
# 1                  21.0
# 2                  15.0

# %%
broken_df[:3]
# Out:
#          Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0  01/01/2012      00:00                 16      35             51
# 1  02/01/2012      00:00                 43      83            153
# 2  03/01/2012      00:00                 58     135            248
#
#    Maisonneuve_1  Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# 0             38      5.0    26       10                            0
# 1             68     11.0    53        6                            1
# 2            104      2.0    89        3                            2
#
#    Pont_Jacques_Cartier
# 0                  27.0
# 1                  21.0
# 2                  15.0

# %%
fixed_df = pd.read_csv('bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
fixed_df[:3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-fe54227f86a7> in <module>()
# ----> 1 fixed_df = pd.read_csv('bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
#       2 fixed_df[:3]
#
# ...

# %%
broken_df['Berri1']
# Out:
# 0        35
# 1        83
# 2       135
# 3       144
# 4       197
# 5       146
# 6        98
# 7        95
# 8       244
# 9       397
# 10      273
# 11      157
# 12       75
# 13       32
# 14       54
# 15      168
# 16      155
# 17      139
# 18      191
# 19      161
# 20       53
# 21       71
# 22      210
# 23      299
# 24      334
# 25      306
# 26       91
# 27       80
# 28       87
# 29      219
#        ...
# 336     324
# 337    1286
# 338    1264
# 339    1204
# 340    1252
# 341    1151
# 342     382
# 343     427
# 344     245
# 345     517
# 346     598
# 347     655
# 348     738
# 349     335
# 350     177
# 351     236
# 352     242
# 353     346
# 354     433
# 355     178
# 356      84
# 357      82
# 358      51
# 359      26
# 360      49
# 361      12
# 362      35
# 363      27
# 364       5
# 365       4
# Name: Berri1, Length: 366, dtype: int64

# %%
pd.read_csv?

# %%
broken_df['Berri1'].plot()

# %%
broken_df.plot(figsize = (15,10))

# %%
df = pd.read_csv('bikes.csv')
df['Berri1'].plot()
